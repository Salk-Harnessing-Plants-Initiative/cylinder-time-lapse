# %%
import numpy as np
import h5py
from pathlib import Path
import imageio as iio
import re

# %%
def natural_sort(l):
    """Sort a list of strings in a way that considers numerical values within the strings.
    
    For example, natural_sort(["img2.png", "img10.png", "img1.png"])
    will return ["img1.png", "img2.png", "img10.png"].
    
    Args:
        l (list): List of strings to sort.
    
    Returns:
        list: List of sorted strings.
    """
    l = [x.as_posix() if isinstance(x, Path) else x for x in l]
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [convert(c) for c in re.split('([0-9]+)', key)]
    return sorted(l, key=alphanum_key)

# %%
base_src_dir = "Arabidopsis"  # Adjust to your source directory
base_dst_dir = "Arabidopsis_time_lapse_videos_20240807/h5s_preds_by_frame"  # Adjust to your destination directory
genotypes = range(1,7) # 1 to 6
img_numbers = range(1, 73)  # 1 to 72
days = range(1, 19)  # 1 to 18
overwrite = False # When overwrite=True existing files are overwritten
print(f"genotypes: {genotypes}")
print(f"image numbers: {img_numbers}")
print(f"days: {days}")
# Out:
# genotypes: range(1, 7)
# image numbers: range(1, 73)
# days: range(1, 19)

# %%
base_src_dir = Path(base_src_dir)
base_dst_dir = Path(base_dst_dir)

# Create the destination directory if it doesn't exist
base_dst_dir.mkdir(parents=True, exist_ok=True)
print(f"Destination directory: {base_dst_dir}")

# Iterate over genotypes and replicates
for genotype in genotypes:
    for replicate_dir in (base_src_dir / str(genotype)).glob('*d/R*'):
        replicate = replicate_dir.name
        h5_name = base_dst_dir / f"g{genotype}_r{replicate}.h5"
        print(f"\nProcessing genotype {genotype}, replicate {replicate}")

        if not overwrite and h5_name.exists():
            print(f"Skipping {h5_name} as it already exists and overwrite is False.")
            continue

        images = []

        # Iterate over days
        for day in days:
            print(f"day: {day}")
            day_dir = base_src_dir / str(genotype) / f"{day}d" / replicate
            if not day_dir.exists():
                continue
            
            # Collect image paths for the current day
            day_images = []
            missing_images = False
            for img_number in img_numbers:
                img_path = day_dir / f"{img_number}.png"
                if img_path.exists():
                    day_images.append(img_path)
                else:
                    print(f"  Missing image: {img_path}")
                    missing_images = True

            # Skip this day if any images are missing
            if missing_images:
                print(f"Skipping day {day} for genotype {genotype}, replicate {replicate} due to missing images.")
                continue
            
            # Sort the images for the current day
            day_images = natural_sort(day_images)
            
            # Read and append images to the list
            for img_path in day_images:
                images.append(iio.imread(img_path))

        if images:
            vol = np.stack(images, axis=0)  # Stack images to create a volume (slices, height, width)
            # Save as h5
            with h5py.File(h5_name, "w") as f:
                f.create_dataset(
                    "vol",
                    data=np.expand_dims(vol, axis=-1),  # Add channel dimension
                    compression="gzip",  # Using gzip compression
                    compression_opts=1  # Compression level
                )
            print(f"Time-lapse video for genotype {genotype}, replicate {replicate} saved successfully as {h5_name}.")
        else:
            print(f"No images found for genotype {genotype}, replicate {replicate}. Skipping.")
# Out:
# Destination directory: Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame
#
# Processing genotype 1, replicate R1
# day: 1
# C:\Users\eb\.conda\envs\sleap_v1.3.3\lib\site-packages\ipykernel_launcher.py:49: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
# day: 2
# day: 3
# day: 4
# day: 5
# day: 6
# day: 7
# day: 8
# day: 9
# day: 10
# day: 11
# day: 12
#   Missing image: Arabidopsis\1\12d\R1\2.png
#   Missing image: Arabidopsis\1\12d\R1\3.png
#   Missing image: Arabidopsis\1\12d\R1\4.png
#   Missing image: Arabidopsis\1\12d\R1\5.png
#   Missing image: Arabidopsis\1\12d\R1\6.png
#   Missing image: Arabidopsis\1\12d\R1\7.png
#   Missing image: Arabidopsis\1\12d\R1\8.png
#   Missing image: Arabidopsis\1\12d\R1\9.png
#   Missing image: Arabidopsis\1\12d\R1\10.png
#   Missing image: Arabidopsis\1\12d\R1\11.png
#   Missing image: Arabidopsis\1\12d\R1\12.png
#   Missing image: Arabidopsis\1\12d\R1\13.png
#   Missing image: Arabidopsis\1\12d\R1\14.png
#   Missing image: Arabidopsis\1\12d\R1\15.png
#   Missing image: Arabidopsis\1\12d\R1\16.png
#   Missing image: Arabidopsis\1\12d\R1\17.png
#   Missing image: Arabidopsis\1\12d\R1\18.png
#   Missing image: Arabidopsis\1\12d\R1\19.png
#   Missing image: Arabidopsis\1\12d\R1\20.png
#   Missing image: Arabidopsis\1\12d\R1\21.png
#   Missing image: Arabidopsis\1\12d\R1\22.png
#   Missing image: Arabidopsis\1\12d\R1\23.png
#   Missing image: Arabidopsis\1\12d\R1\24.png
#   Missing image: Arabidopsis\1\12d\R1\25.png
#   Missing image: Arabidopsis\1\12d\R1\26.png
#   Missing image: Arabidopsis\1\12d\R1\27.png
#   Missing image: Arabidopsis\1\12d\R1\28.png
#   Missing image: Arabidopsis\1\12d\R1\29.png
#   Missing image: Arabidopsis\1\12d\R1\30.png
#   Missing image: Arabidopsis\1\12d\R1\31.png
#   Missing image: Arabidopsis\1\12d\R1\32.png
#   Missing image: Arabidopsis\1\12d\R1\33.png
#   Missing image: Arabidopsis\1\12d\R1\34.png
#   Missing image: Arabidopsis\1\12d\R1\35.png
#   Missing image: Arabidopsis\1\12d\R1\36.png
#   Missing image: Arabidopsis\1\12d\R1\37.png
#   Missing image: Arabidopsis\1\12d\R1\38.png
#   Missing image: Arabidopsis\1\12d\R1\39.png
#   Missing image: Arabidopsis\1\12d\R1\40.png
#   Missing image: Arabidopsis\1\12d\R1\41.png
#   Missing image: Arabidopsis\1\12d\R1\42.png
#   Missing image: Arabidopsis\1\12d\R1\43.png
#   Missing image: Arabidopsis\1\12d\R1\44.png
#   Missing image: Arabidopsis\1\12d\R1\45.png
#   Missing image: Arabidopsis\1\12d\R1\46.png
#   Missing image: Arabidopsis\1\12d\R1\47.png
#   Missing image: Arabidopsis\1\12d\R1\48.png
#   Missing image: Arabidopsis\1\12d\R1\49.png
#   Missing image: Arabidopsis\1\12d\R1\50.png
#   Missing image: Arabidopsis\1\12d\R1\51.png
#   Missing image: Arabidopsis\1\12d\R1\52.png
#   Missing image: Arabidopsis\1\12d\R1\53.png
#   Missing image: Arabidopsis\1\12d\R1\54.png
#   Missing image: Arabidopsis\1\12d\R1\55.png
#   Missing image: Arabidopsis\1\12d\R1\56.png
#   Missing image: Arabidopsis\1\12d\R1\57.png
#   Missing image: Arabidopsis\1\12d\R1\58.png
#   Missing image: Arabidopsis\1\12d\R1\59.png
#   Missing image: Arabidopsis\1\12d\R1\60.png
#   Missing image: Arabidopsis\1\12d\R1\61.png
#   Missing image: Arabidopsis\1\12d\R1\62.png
#   Missing image: Arabidopsis\1\12d\R1\63.png
#   Missing image: Arabidopsis\1\12d\R1\64.png
#   Missing image: Arabidopsis\1\12d\R1\65.png
#   Missing image: Arabidopsis\1\12d\R1\66.png
#   Missing image: Arabidopsis\1\12d\R1\67.png
#   Missing image: Arabidopsis\1\12d\R1\68.png
#   Missing image: Arabidopsis\1\12d\R1\69.png
#   Missing image: Arabidopsis\1\12d\R1\70.png
#   Missing image: Arabidopsis\1\12d\R1\71.png
#   Missing image: Arabidopsis\1\12d\R1\72.png
# Skipping day 12 for genotype 1, replicate R1 due to missing images.
# day: 13
# day: 14
# day: 15
# day: 16
# day: 17
# day: 18
# Time-lapse video for genotype 1, replicate R1 saved successfully as Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR1.h5.
#
# Processing genotype 1, replicate R2
# day: 1
# day: 2
# day: 3
# day: 4
# day: 5
# day: 6
# day: 7
# day: 8
# day: 9
# day: 10
# day: 11
# day: 12
#   Missing image: Arabidopsis\1\12d\R2\2.png
#   Missing image: Arabidopsis\1\12d\R2\3.png
#   Missing image: Arabidopsis\1\12d\R2\4.png
#   Missing image: Arabidopsis\1\12d\R2\5.png
#   Missing image: Arabidopsis\1\12d\R2\6.png
#   Missing image: Arabidopsis\1\12d\R2\7.png
#   Missing image: Arabidopsis\1\12d\R2\8.png
#   Missing image: Arabidopsis\1\12d\R2\9.png
#   Missing image: Arabidopsis\1\12d\R2\10.png
#   Missing image: Arabidopsis\1\12d\R2\11.png
#   Missing image: Arabidopsis\1\12d\R2\12.png
#   Missing image: Arabidopsis\1\12d\R2\13.png
#   Missing image: Arabidopsis\1\12d\R2\14.png
#   Missing image: Arabidopsis\1\12d\R2\15.png
#   Missing image: Arabidopsis\1\12d\R2\16.png
#   Missing image: Arabidopsis\1\12d\R2\17.png
#   Missing image: Arabidopsis\1\12d\R2\18.png
#   Missing image: Arabidopsis\1\12d\R2\19.png
#   Missing image: Arabidopsis\1\12d\R2\20.png
#   Missing image: Arabidopsis\1\12d\R2\21.png
#   Missing image: Arabidopsis\1\12d\R2\22.png
#   Missing image: Arabidopsis\1\12d\R2\23.png
#   Missing image: Arabidopsis\1\12d\R2\24.png
#   Missing image: Arabidopsis\1\12d\R2\25.png
#   Missing image: Arabidopsis\1\12d\R2\26.png
#   Missing image: Arabidopsis\1\12d\R2\27.png
#   Missing image: Arabidopsis\1\12d\R2\28.png
#   Missing image: Arabidopsis\1\12d\R2\29.png
#   Missing image: Arabidopsis\1\12d\R2\30.png
#   Missing image: Arabidopsis\1\12d\R2\31.png
#   Missing image: Arabidopsis\1\12d\R2\32.png
#   Missing image: Arabidopsis\1\12d\R2\33.png
#   Missing image: Arabidopsis\1\12d\R2\34.png
#   Missing image: Arabidopsis\1\12d\R2\35.png
#   Missing image: Arabidopsis\1\12d\R2\36.png
#   Missing image: Arabidopsis\1\12d\R2\37.png
#   Missing image: Arabidopsis\1\12d\R2\38.png
#   Missing image: Arabidopsis\1\12d\R2\39.png
#   Missing image: Arabidopsis\1\12d\R2\40.png
#   Missing image: Arabidopsis\1\12d\R2\41.png
#   Missing image: Arabidopsis\1\12d\R2\42.png
#   Missing image: Arabidopsis\1\12d\R2\43.png
#   Missing image: Arabidopsis\1\12d\R2\44.png
#   Missing image: Arabidopsis\1\12d\R2\45.png
#   Missing image: Arabidopsis\1\12d\R2\46.png
#   Missing image: Arabidopsis\1\12d\R2\47.png
#   Missing image: Arabidopsis\1\12d\R2\48.png
#   Missing image: Arabidopsis\1\12d\R2\49.png
#   Missing image: Arabidopsis\1\12d\R2\50.png
#   Missing image: Arabidopsis\1\12d\R2\51.png
#   Missing image: Arabidopsis\1\12d\R2\52.png
#   Missing image: Arabidopsis\1\12d\R2\53.png
#   Missing image: Arabidopsis\1\12d\R2\54.png
#   Missing image: Arabidopsis\1\12d\R2\55.png
#   Missing image: Arabidopsis\1\12d\R2\56.png
#   Missing image: Arabidopsis\1\12d\R2\57.png
#   Missing image: Arabidopsis\1\12d\R2\58.png
#   Missing image: Arabidopsis\1\12d\R2\59.png
#   Missing image: Arabidopsis\1\12d\R2\60.png
#   Missing image: Arabidopsis\1\12d\R2\61.png
#   Missing image: Arabidopsis\1\12d\R2\62.png
#   Missing image: Arabidopsis\1\12d\R2\63.png
#   Missing image: Arabidopsis\1\12d\R2\64.png
#   Missing image: Arabidopsis\1\12d\R2\65.png
#   Missing image: Arabidopsis\1\12d\R2\66.png
#   Missing image: Arabidopsis\1\12d\R2\67.png
#   Missing image: Arabidopsis\1\12d\R2\68.png
#   Missing image: Arabidopsis\1\12d\R2\69.png
#   Missing image: Arabidopsis\1\12d\R2\70.png
#   Missing image: Arabidopsis\1\12d\R2\71.png
#   Missing image: Arabidopsis\1\12d\R2\72.png
# Skipping day 12 for genotype 1, replicate R2 due to missing images.
# day: 13
# day: 14
# day: 15
# day: 16
# day: 17
# day: 18
# Time-lapse video for genotype 1, replicate R2 saved successfully as Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR2.h5.
#
# Processing genotype 1, replicate R3
# day: 1
# day: 2
# day: 3
# day: 4
# day: 5
# day: 6
# day: 7
# day: 8
# day: 9
# day: 10
# day: 11
# day: 12
#   Missing image: Arabidopsis\1\12d\R3\2.png
#   Missing image: Arabidopsis\1\12d\R3\3.png
#   Missing image: Arabidopsis\1\12d\R3\4.png
#   Missing image: Arabidopsis\1\12d\R3\5.png
#   Missing image: Arabidopsis\1\12d\R3\6.png
#   Missing image: Arabidopsis\1\12d\R3\7.png
#   Missing image: Arabidopsis\1\12d\R3\8.png
#   Missing image: Arabidopsis\1\12d\R3\9.png
#   Missing image: Arabidopsis\1\12d\R3\10.png
#   Missing image: Arabidopsis\1\12d\R3\11.png
#   Missing image: Arabidopsis\1\12d\R3\12.png
#   Missing image: Arabidopsis\1\12d\R3\13.png
#   Missing image: Arabidopsis\1\12d\R3\14.png
#   Missing image: Arabidopsis\1\12d\R3\15.png
#   Missing image: Arabidopsis\1\12d\R3\16.png
#   Missing image: Arabidopsis\1\12d\R3\17.png
#   Missing image: Arabidopsis\1\12d\R3\18.png
#   Missing image: Arabidopsis\1\12d\R3\19.png
#   Missing image: Arabidopsis\1\12d\R3\20.png
#   Missing image: Arabidopsis\1\12d\R3\21.png
#   Missing image: Arabidopsis\1\12d\R3\22.png
#   Missing image: Arabidopsis\1\12d\R3\23.png
#   Missing image: Arabidopsis\1\12d\R3\24.png
#   Missing image: Arabidopsis\1\12d\R3\25.png
#   Missing image: Arabidopsis\1\12d\R3\26.png
#   Missing image: Arabidopsis\1\12d\R3\27.png
#   Missing image: Arabidopsis\1\12d\R3\28.png
#   Missing image: Arabidopsis\1\12d\R3\29.png
#   Missing image: Arabidopsis\1\12d\R3\30.png
#   Missing image: Arabidopsis\1\12d\R3\31.png
#   Missing image: Arabidopsis\1\12d\R3\32.png
#   Missing image: Arabidopsis\1\12d\R3\33.png
#   Missing image: Arabidopsis\1\12d\R3\34.png
#   Missing image: Arabidopsis\1\12d\R3\35.png
#   Missing image: Arabidopsis\1\12d\R3\36.png
#   Missing image: Arabidopsis\1\12d\R3\37.png
#   Missing image: Arabidopsis\1\12d\R3\38.png
#   Missing image: Arabidopsis\1\12d\R3\39.png
#   Missing image: Arabidopsis\1\12d\R3\40.png
#   Missing image: Arabidopsis\1\12d\R3\41.png
#   Missing image: Arabidopsis\1\12d\R3\42.png
#   Missing image: Arabidopsis\1\12d\R3\43.png
#   Missing image: Arabidopsis\1\12d\R3\44.png
#   Missing image: Arabidopsis\1\12d\R3\45.png
#   Missing image: Arabidopsis\1\12d\R3\46.png
#   Missing image: Arabidopsis\1\12d\R3\47.png
#   Missing image: Arabidopsis\1\12d\R3\48.png
#   Missing image: Arabidopsis\1\12d\R3\49.png
#   Missing image: Arabidopsis\1\12d\R3\50.png
#   Missing image: Arabidopsis\1\12d\R3\51.png
#   Missing image: Arabidopsis\1\12d\R3\52.png
#   Missing image: Arabidopsis\1\12d\R3\53.png
#   Missing image: Arabidopsis\1\12d\R3\54.png
#   Missing image: Arabidopsis\1\12d\R3\55.png
#   Missing image: Arabidopsis\1\12d\R3\56.png
#   Missing image: Arabidopsis\1\12d\R3\57.png
#   Missing image: Arabidopsis\1\12d\R3\58.png
#   Missing image: Arabidopsis\1\12d\R3\59.png
#   Missing image: Arabidopsis\1\12d\R3\60.png
#   Missing image: Arabidopsis\1\12d\R3\61.png
#   Missing image: Arabidopsis\1\12d\R3\62.png
#   Missing image: Arabidopsis\1\12d\R3\63.png
#   Missing image: Arabidopsis\1\12d\R3\64.png
#   Missing image: Arabidopsis\1\12d\R3\65.png
#   Missing image: Arabidopsis\1\12d\R3\66.png
#   Missing image: Arabidopsis\1\12d\R3\67.png
#   Missing image: Arabidopsis\1\12d\R3\68.png
#   Missing image: Arabidopsis\1\12d\R3\69.png
#   Missing image: Arabidopsis\1\12d\R3\70.png
#   Missing image: Arabidopsis\1\12d\R3\71.png
#   Missing image: Arabidopsis\1\12d\R3\72.png
# Skipping day 12 for genotype 1, replicate R3 due to missing images.
# day: 13
# day: 14
# day: 15
# day: 16
# day: 17
# day: 18
# Time-lapse video for genotype 1, replicate R3 saved successfully as Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR3.h5.
#
# Processing genotype 1, replicate R4
# day: 1
# day: 2
# day: 3
# day: 4
# day: 5
# day: 6
# day: 7
# day: 8
# day: 9
# day: 10
# day: 11
# day: 12
#   Missing image: Arabidopsis\1\12d\R4\2.png
#   Missing image: Arabidopsis\1\12d\R4\3.png
#   Missing image: Arabidopsis\1\12d\R4\4.png
#   Missing image: Arabidopsis\1\12d\R4\5.png
#   Missing image: Arabidopsis\1\12d\R4\6.png
#   Missing image: Arabidopsis\1\12d\R4\7.png
#   Missing image: Arabidopsis\1\12d\R4\8.png
#   Missing image: Arabidopsis\1\12d\R4\9.png
#   Missing image: Arabidopsis\1\12d\R4\10.png
#   Missing image: Arabidopsis\1\12d\R4\11.png
#   Missing image: Arabidopsis\1\12d\R4\12.png
#   Missing image: Arabidopsis\1\12d\R4\13.png
#   Missing image: Arabidopsis\1\12d\R4\14.png
#   Missing image: Arabidopsis\1\12d\R4\15.png
#   Missing image: Arabidopsis\1\12d\R4\16.png
#   Missing image: Arabidopsis\1\12d\R4\17.png
#   Missing image: Arabidopsis\1\12d\R4\18.png
#   Missing image: Arabidopsis\1\12d\R4\19.png
#   Missing image: Arabidopsis\1\12d\R4\20.png
#   Missing image: Arabidopsis\1\12d\R4\21.png
#   Missing image: Arabidopsis\1\12d\R4\22.png
#   Missing image: Arabidopsis\1\12d\R4\23.png
#   Missing image: Arabidopsis\1\12d\R4\24.png
#   Missing image: Arabidopsis\1\12d\R4\25.png
#   Missing image: Arabidopsis\1\12d\R4\26.png
#   Missing image: Arabidopsis\1\12d\R4\27.png
#   Missing image: Arabidopsis\1\12d\R4\28.png
#   Missing image: Arabidopsis\1\12d\R4\29.png
#   Missing image: Arabidopsis\1\12d\R4\30.png
#   Missing image: Arabidopsis\1\12d\R4\31.png
#   Missing image: Arabidopsis\1\12d\R4\32.png
#   Missing image: Arabidopsis\1\12d\R4\33.png
#   Missing image: Arabidopsis\1\12d\R4\34.png
#   Missing image: Arabidopsis\1\12d\R4\35.png
#   Missing image: Arabidopsis\1\12d\R4\36.png
#   Missing image: Arabidopsis\1\12d\R4\37.png
#   Missing image: Arabidopsis\1\12d\R4\38.png
#   Missing image: Arabidopsis\1\12d\R4\39.png
#   Missing image: Arabidopsis\1\12d\R4\40.png
#   Missing image: Arabidopsis\1\12d\R4\41.png
#   Missing image: Arabidopsis\1\12d\R4\42.png
#   Missing image: Arabidopsis\1\12d\R4\43.png
#   Missing image: Arabidopsis\1\12d\R4\44.png
#   Missing image: Arabidopsis\1\12d\R4\45.png
#   Missing image: Arabidopsis\1\12d\R4\46.png
#   Missing image: Arabidopsis\1\12d\R4\47.png
#   Missing image: Arabidopsis\1\12d\R4\48.png
#   Missing image: Arabidopsis\1\12d\R4\49.png
#   Missing image: Arabidopsis\1\12d\R4\50.png
#   Missing image: Arabidopsis\1\12d\R4\51.png
#   Missing image: Arabidopsis\1\12d\R4\52.png
#   Missing image: Arabidopsis\1\12d\R4\53.png
#   Missing image: Arabidopsis\1\12d\R4\54.png
#   Missing image: Arabidopsis\1\12d\R4\55.png
#   Missing image: Arabidopsis\1\12d\R4\56.png
#   Missing image: Arabidopsis\1\12d\R4\57.png
#   Missing image: Arabidopsis\1\12d\R4\58.png
#   Missing image: Arabidopsis\1\12d\R4\59.png
#   Missing image: Arabidopsis\1\12d\R4\60.png
#   Missing image: Arabidopsis\1\12d\R4\61.png
#   Missing image: Arabidopsis\1\12d\R4\62.png
#   Missing image: Arabidopsis\1\12d\R4\63.png
#   Missing image: Arabidopsis\1\12d\R4\64.png
#   Missing image: Arabidopsis\1\12d\R4\65.png
#   Missing image: Arabidopsis\1\12d\R4\66.png
#   Missing image: Arabidopsis\1\12d\R4\67.png
#   Missing image: Arabidopsis\1\12d\R4\68.png
#   Missing image: Arabidopsis\1\12d\R4\69.png
#   Missing image: Arabidopsis\1\12d\R4\70.png
#   Missing image: Arabidopsis\1\12d\R4\71.png
#   Missing image: Arabidopsis\1\12d\R4\72.png
# Skipping day 12 for genotype 1, replicate R4 due to missing images.
# day: 13
# day: 14
# day: 15
# day: 16
# day: 17
# day: 18
# Time-lapse video for genotype 1, replicate R4 saved successfully as Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR4.h5.
#
# Processing genotype 1, replicate R5
# day: 1
# day: 2
# day: 3
# day: 4
# day: 5
# day: 6
# day: 7
# day: 8
# day: 9
# day: 10
# day: 11
# day: 12
#   Missing image: Arabidopsis\1\12d\R5\2.png
#   Missing image: Arabidopsis\1\12d\R5\3.png
#   Missing image: Arabidopsis\1\12d\R5\4.png
#   Missing image: Arabidopsis\1\12d\R5\5.png
#   Missing image: Arabidopsis\1\12d\R5\6.png
#   Missing image: Arabidopsis\1\12d\R5\7.png
#   Missing image: Arabidopsis\1\12d\R5\8.png
#   Missing image: Arabidopsis\1\12d\R5\9.png
#   Missing image: Arabidopsis\1\12d\R5\10.png
#   Missing image: Arabidopsis\1\12d\R5\11.png
#   Missing image: Arabidopsis\1\12d\R5\12.png
#   Missing image: Arabidopsis\1\12d\R5\13.png
#   Missing image: Arabidopsis\1\12d\R5\14.png
#   Missing image: Arabidopsis\1\12d\R5\15.png
#   Missing image: Arabidopsis\1\12d\R5\16.png
#   Missing image: Arabidopsis\1\12d\R5\17.png
#   Missing image: Arabidopsis\1\12d\R5\18.png
#   Missing image: Arabidopsis\1\12d\R5\19.png
#   Missing image: Arabidopsis\1\12d\R5\20.png
#   Missing image: Arabidopsis\1\12d\R5\21.png
#   Missing image: Arabidopsis\1\12d\R5\22.png
#   Missing image: Arabidopsis\1\12d\R5\23.png
#   Missing image: Arabidopsis\1\12d\R5\24.png
#   Missing image: Arabidopsis\1\12d\R5\25.png
#   Missing image: Arabidopsis\1\12d\R5\26.png
#   Missing image: Arabidopsis\1\12d\R5\27.png
#   Missing image: Arabidopsis\1\12d\R5\28.png
#   Missing image: Arabidopsis\1\12d\R5\29.png
#   Missing image: Arabidopsis\1\12d\R5\30.png
#   Missing image: Arabidopsis\1\12d\R5\31.png
#   Missing image: Arabidopsis\1\12d\R5\32.png
#   Missing image: Arabidopsis\1\12d\R5\33.png
#   Missing image: Arabidopsis\1\12d\R5\34.png
#   Missing image: Arabidopsis\1\12d\R5\35.png
#   Missing image: Arabidopsis\1\12d\R5\36.png
#   Missing image: Arabidopsis\1\12d\R5\37.png
#   Missing image: Arabidopsis\1\12d\R5\38.png
#   Missing image: Arabidopsis\1\12d\R5\39.png
#   Missing image: Arabidopsis\1\12d\R5\40.png
#   Missing image: Arabidopsis\1\12d\R5\41.png
#   Missing image: Arabidopsis\1\12d\R5\42.png
#   Missing image: Arabidopsis\1\12d\R5\43.png
#   Missing image: Arabidopsis\1\12d\R5\44.png
#   Missing image: Arabidopsis\1\12d\R5\45.png
#   Missing image: Arabidopsis\1\12d\R5\46.png
#   Missing image: Arabidopsis\1\12d\R5\47.png
#   Missing image: Arabidopsis\1\12d\R5\48.png
#   Missing image: Arabidopsis\1\12d\R5\49.png
#   Missing image: Arabidopsis\1\12d\R5\50.png
#   Missing image: Arabidopsis\1\12d\R5\51.png
#   Missing image: Arabidopsis\1\12d\R5\52.png
#   Missing image: Arabidopsis\1\12d\R5\53.png
#   Missing image: Arabidopsis\1\12d\R5\54.png
#   Missing image: Arabidopsis\1\12d\R5\55.png
#   Missing image: Arabidopsis\1\12d\R5\56.png
#   Missing image: Arabidopsis\1\12d\R5\57.png
#   Missing image: Arabidopsis\1\12d\R5\58.png
#   Missing image: Arabidopsis\1\12d\R5\59.png
#   Missing image: Arabidopsis\1\12d\R5\60.png
#   Missing image: Arabidopsis\1\12d\R5\61.png
#   Missing image: Arabidopsis\1\12d\R5\62.png
#   Missing image: Arabidopsis\1\12d\R5\63.png
#   Missing image: Arabidopsis\1\12d\R5\64.png
#   Missing image: Arabidopsis\1\12d\R5\65.png
#   Missing image: Arabidopsis\1\12d\R5\66.png
#   Missing image: Arabidopsis\1\12d\R5\67.png
#   Missing image: Arabidopsis\1\12d\R5\68.png
#   Missing image: Arabidopsis\1\12d\R5\69.png
#   Missing image: Arabidopsis\1\12d\R5\70.png
#   Missing image: Arabidopsis\1\12d\R5\71.png
#   Missing image: Arabidopsis\1\12d\R5\72.png
# Skipping day 12 for genotype 1, replicate R5 due to missing images.
# day: 13
# day: 14
# day: 15
# day: 16
# day: 17
# day: 18
# Time-lapse video for genotype 1, replicate R5 saved successfully as Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR5.h5.
#
# Processing genotype 1, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 1, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g1_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 2, replicate R1
# day: 1
# day: 2
# day: 3
# day: 4
# day: 5
# day: 6
# day: 7
# day: 8
# day: 9
# day: 10
# day: 11
# day: 12
#   Missing image: Arabidopsis\2\12d\R1\2.png
#   Missing image: Arabidopsis\2\12d\R1\3.png
#   Missing image: Arabidopsis\2\12d\R1\4.png
#   Missing image: Arabidopsis\2\12d\R1\5.png
#   Missing image: Arabidopsis\2\12d\R1\6.png
#   Missing image: Arabidopsis\2\12d\R1\7.png
#   Missing image: Arabidopsis\2\12d\R1\8.png
#   Missing image: Arabidopsis\2\12d\R1\9.png
#   Missing image: Arabidopsis\2\12d\R1\10.png
#   Missing image: Arabidopsis\2\12d\R1\11.png
#   Missing image: Arabidopsis\2\12d\R1\12.png
#   Missing image: Arabidopsis\2\12d\R1\13.png
#   Missing image: Arabidopsis\2\12d\R1\14.png
#   Missing image: Arabidopsis\2\12d\R1\15.png
#   Missing image: Arabidopsis\2\12d\R1\16.png
#   Missing image: Arabidopsis\2\12d\R1\17.png
#   Missing image: Arabidopsis\2\12d\R1\18.png
#   Missing image: Arabidopsis\2\12d\R1\19.png
#   Missing image: Arabidopsis\2\12d\R1\20.png
#   Missing image: Arabidopsis\2\12d\R1\21.png
#   Missing image: Arabidopsis\2\12d\R1\22.png
#   Missing image: Arabidopsis\2\12d\R1\23.png
#   Missing image: Arabidopsis\2\12d\R1\24.png
#   Missing image: Arabidopsis\2\12d\R1\25.png
#   Missing image: Arabidopsis\2\12d\R1\26.png
#   Missing image: Arabidopsis\2\12d\R1\27.png
#   Missing image: Arabidopsis\2\12d\R1\28.png
#   Missing image: Arabidopsis\2\12d\R1\29.png
#   Missing image: Arabidopsis\2\12d\R1\30.png
#   Missing image: Arabidopsis\2\12d\R1\31.png
#   Missing image: Arabidopsis\2\12d\R1\32.png
#   Missing image: Arabidopsis\2\12d\R1\33.png
#   Missing image: Arabidopsis\2\12d\R1\34.png
#   Missing image: Arabidopsis\2\12d\R1\35.png
#   Missing image: Arabidopsis\2\12d\R1\36.png
#   Missing image: Arabidopsis\2\12d\R1\37.png
#   Missing image: Arabidopsis\2\12d\R1\38.png
#   Missing image: Arabidopsis\2\12d\R1\39.png
#   Missing image: Arabidopsis\2\12d\R1\40.png
#   Missing image: Arabidopsis\2\12d\R1\41.png
#   Missing image: Arabidopsis\2\12d\R1\42.png
#   Missing image: Arabidopsis\2\12d\R1\43.png
#   Missing image: Arabidopsis\2\12d\R1\44.png
#   Missing image: Arabidopsis\2\12d\R1\45.png
#   Missing image: Arabidopsis\2\12d\R1\46.png
#   Missing image: Arabidopsis\2\12d\R1\47.png
#   Missing image: Arabidopsis\2\12d\R1\48.png
#   Missing image: Arabidopsis\2\12d\R1\49.png
#   Missing image: Arabidopsis\2\12d\R1\50.png
#   Missing image: Arabidopsis\2\12d\R1\51.png
#   Missing image: Arabidopsis\2\12d\R1\52.png
#   Missing image: Arabidopsis\2\12d\R1\53.png
#   Missing image: Arabidopsis\2\12d\R1\54.png
#   Missing image: Arabidopsis\2\12d\R1\55.png
#   Missing image: Arabidopsis\2\12d\R1\56.png
#   Missing image: Arabidopsis\2\12d\R1\57.png
#   Missing image: Arabidopsis\2\12d\R1\58.png
#   Missing image: Arabidopsis\2\12d\R1\59.png
#   Missing image: Arabidopsis\2\12d\R1\60.png
#   Missing image: Arabidopsis\2\12d\R1\61.png
#   Missing image: Arabidopsis\2\12d\R1\62.png
#   Missing image: Arabidopsis\2\12d\R1\63.png
#   Missing image: Arabidopsis\2\12d\R1\64.png
#   Missing image: Arabidopsis\2\12d\R1\65.png
#   Missing image: Arabidopsis\2\12d\R1\66.png
#   Missing image: Arabidopsis\2\12d\R1\67.png
#   Missing image: Arabidopsis\2\12d\R1\68.png
#   Missing image: Arabidopsis\2\12d\R1\69.png
#   Missing image: Arabidopsis\2\12d\R1\70.png
#   Missing image: Arabidopsis\2\12d\R1\71.png
#   Missing image: Arabidopsis\2\12d\R1\72.png
# Skipping day 12 for genotype 2, replicate R1 due to missing images.
# day: 13
# day: 14
# day: 15
# day: 16
# day: 17
# day: 18
# Time-lapse video for genotype 2, replicate R1 saved successfully as Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g2_rR1.h5.
#
# Processing genotype 2, replicate R2
# day: 1
# day: 2
# day: 3
# day: 4
# day: 5
# day: 6
# day: 7
# day: 8
# day: 9
# day: 10
# day: 11
# day: 12
#   Missing image: Arabidopsis\2\12d\R2\2.png
#   Missing image: Arabidopsis\2\12d\R2\3.png
#   Missing image: Arabidopsis\2\12d\R2\4.png
#   Missing image: Arabidopsis\2\12d\R2\5.png
#   Missing image: Arabidopsis\2\12d\R2\6.png
#   Missing image: Arabidopsis\2\12d\R2\7.png
#   Missing image: Arabidopsis\2\12d\R2\8.png
#   Missing image: Arabidopsis\2\12d\R2\9.png
#   Missing image: Arabidopsis\2\12d\R2\10.png
#   Missing image: Arabidopsis\2\12d\R2\11.png
#   Missing image: Arabidopsis\2\12d\R2\12.png
#   Missing image: Arabidopsis\2\12d\R2\13.png
#   Missing image: Arabidopsis\2\12d\R2\14.png
#   Missing image: Arabidopsis\2\12d\R2\15.png
#   Missing image: Arabidopsis\2\12d\R2\16.png
#   Missing image: Arabidopsis\2\12d\R2\17.png
#   Missing image: Arabidopsis\2\12d\R2\18.png
#   Missing image: Arabidopsis\2\12d\R2\19.png
#   Missing image: Arabidopsis\2\12d\R2\20.png
#   Missing image: Arabidopsis\2\12d\R2\21.png
#   Missing image: Arabidopsis\2\12d\R2\22.png
#   Missing image: Arabidopsis\2\12d\R2\23.png
#   Missing image: Arabidopsis\2\12d\R2\24.png
#   Missing image: Arabidopsis\2\12d\R2\25.png
#   Missing image: Arabidopsis\2\12d\R2\26.png
#   Missing image: Arabidopsis\2\12d\R2\27.png
#   Missing image: Arabidopsis\2\12d\R2\28.png
#   Missing image: Arabidopsis\2\12d\R2\29.png
#   Missing image: Arabidopsis\2\12d\R2\30.png
#   Missing image: Arabidopsis\2\12d\R2\31.png
#   Missing image: Arabidopsis\2\12d\R2\32.png
#   Missing image: Arabidopsis\2\12d\R2\33.png
#   Missing image: Arabidopsis\2\12d\R2\34.png
#   Missing image: Arabidopsis\2\12d\R2\35.png
#   Missing image: Arabidopsis\2\12d\R2\36.png
#   Missing image: Arabidopsis\2\12d\R2\37.png
#   Missing image: Arabidopsis\2\12d\R2\38.png
#   Missing image: Arabidopsis\2\12d\R2\39.png
#   Missing image: Arabidopsis\2\12d\R2\40.png
#   Missing image: Arabidopsis\2\12d\R2\41.png
#   Missing image: Arabidopsis\2\12d\R2\42.png
#   Missing image: Arabidopsis\2\12d\R2\43.png
#   Missing image: Arabidopsis\2\12d\R2\44.png
#   Missing image: Arabidopsis\2\12d\R2\45.png
#   Missing image: Arabidopsis\2\12d\R2\46.png
#   Missing image: Arabidopsis\2\12d\R2\47.png
#   Missing image: Arabidopsis\2\12d\R2\48.png
#   Missing image: Arabidopsis\2\12d\R2\49.png
#   Missing image: Arabidopsis\2\12d\R2\50.png
#   Missing image: Arabidopsis\2\12d\R2\51.png
#   Missing image: Arabidopsis\2\12d\R2\52.png
#   Missing image: Arabidopsis\2\12d\R2\53.png
#   Missing image: Arabidopsis\2\12d\R2\54.png
#   Missing image: Arabidopsis\2\12d\R2\55.png
#   Missing image: Arabidopsis\2\12d\R2\56.png
#   Missing image: Arabidopsis\2\12d\R2\57.png
#   Missing image: Arabidopsis\2\12d\R2\58.png
#   Missing image: Arabidopsis\2\12d\R2\59.png
#   Missing image: Arabidopsis\2\12d\R2\60.png
#   Missing image: Arabidopsis\2\12d\R2\61.png
#   Missing image: Arabidopsis\2\12d\R2\62.png
#   Missing image: Arabidopsis\2\12d\R2\63.png
#   Missing image: Arabidopsis\2\12d\R2\64.png
#   Missing image: Arabidopsis\2\12d\R2\65.png
#   Missing image: Arabidopsis\2\12d\R2\66.png
#   Missing image: Arabidopsis\2\12d\R2\67.png
#   Missing image: Arabidopsis\2\12d\R2\68.png
#   Missing image: Arabidopsis\2\12d\R2\69.png
#   Missing image: Arabidopsis\2\12d\R2\70.png
#   Missing image: Arabidopsis\2\12d\R2\71.png
#   Missing image: Arabidopsis\2\12d\R2\72.png
# Skipping day 12 for genotype 2, replicate R2 due to missing images.
# day: 13
# day: 14
# day: 15
# day: 16
# day: 17
# day: 18
# Time-lapse video for genotype 2, replicate R2 saved successfully as Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g2_rR2.h5.
#
# Processing genotype 2, replicate R3
# day: 1
# day: 2
# day: 3
# day: 4
# day: 5
# day: 6
# day: 7
# day: 8
# day: 9
# day: 10
# day: 11
# day: 12
#   Missing image: Arabidopsis\2\12d\R3\2.png
#   Missing image: Arabidopsis\2\12d\R3\3.png
#   Missing image: Arabidopsis\2\12d\R3\4.png
#   Missing image: Arabidopsis\2\12d\R3\5.png
#   Missing image: Arabidopsis\2\12d\R3\6.png
#   Missing image: Arabidopsis\2\12d\R3\7.png
#   Missing image: Arabidopsis\2\12d\R3\8.png
#   Missing image: Arabidopsis\2\12d\R3\9.png
#   Missing image: Arabidopsis\2\12d\R3\10.png
#   Missing image: Arabidopsis\2\12d\R3\11.png
#   Missing image: Arabidopsis\2\12d\R3\12.png
#   Missing image: Arabidopsis\2\12d\R3\13.png
#   Missing image: Arabidopsis\2\12d\R3\14.png
#   Missing image: Arabidopsis\2\12d\R3\15.png
#   Missing image: Arabidopsis\2\12d\R3\16.png
#   Missing image: Arabidopsis\2\12d\R3\17.png
#   Missing image: Arabidopsis\2\12d\R3\18.png
#   Missing image: Arabidopsis\2\12d\R3\19.png
#   Missing image: Arabidopsis\2\12d\R3\20.png
#   Missing image: Arabidopsis\2\12d\R3\21.png
#   Missing image: Arabidopsis\2\12d\R3\22.png
#   Missing image: Arabidopsis\2\12d\R3\23.png
#   Missing image: Arabidopsis\2\12d\R3\24.png
#   Missing image: Arabidopsis\2\12d\R3\25.png
#   Missing image: Arabidopsis\2\12d\R3\26.png
#   Missing image: Arabidopsis\2\12d\R3\27.png
#   Missing image: Arabidopsis\2\12d\R3\28.png
#   Missing image: Arabidopsis\2\12d\R3\29.png
#   Missing image: Arabidopsis\2\12d\R3\30.png
#   Missing image: Arabidopsis\2\12d\R3\31.png
#   Missing image: Arabidopsis\2\12d\R3\32.png
#   Missing image: Arabidopsis\2\12d\R3\33.png
#   Missing image: Arabidopsis\2\12d\R3\34.png
#   Missing image: Arabidopsis\2\12d\R3\35.png
#   Missing image: Arabidopsis\2\12d\R3\36.png
#   Missing image: Arabidopsis\2\12d\R3\37.png
#   Missing image: Arabidopsis\2\12d\R3\38.png
#   Missing image: Arabidopsis\2\12d\R3\39.png
#   Missing image: Arabidopsis\2\12d\R3\40.png
#   Missing image: Arabidopsis\2\12d\R3\41.png
#   Missing image: Arabidopsis\2\12d\R3\42.png
#   Missing image: Arabidopsis\2\12d\R3\43.png
#   Missing image: Arabidopsis\2\12d\R3\44.png
#   Missing image: Arabidopsis\2\12d\R3\45.png
#   Missing image: Arabidopsis\2\12d\R3\46.png
#   Missing image: Arabidopsis\2\12d\R3\47.png
#   Missing image: Arabidopsis\2\12d\R3\48.png
#   Missing image: Arabidopsis\2\12d\R3\49.png
#   Missing image: Arabidopsis\2\12d\R3\50.png
#   Missing image: Arabidopsis\2\12d\R3\51.png
#   Missing image: Arabidopsis\2\12d\R3\52.png
#   Missing image: Arabidopsis\2\12d\R3\53.png
#   Missing image: Arabidopsis\2\12d\R3\54.png
#   Missing image: Arabidopsis\2\12d\R3\55.png
#   Missing image: Arabidopsis\2\12d\R3\56.png
#   Missing image: Arabidopsis\2\12d\R3\57.png
#   Missing image: Arabidopsis\2\12d\R3\58.png
#   Missing image: Arabidopsis\2\12d\R3\59.png
#   Missing image: Arabidopsis\2\12d\R3\60.png
#   Missing image: Arabidopsis\2\12d\R3\61.png
#   Missing image: Arabidopsis\2\12d\R3\62.png
#   Missing image: Arabidopsis\2\12d\R3\63.png
#   Missing image: Arabidopsis\2\12d\R3\64.png
#   Missing image: Arabidopsis\2\12d\R3\65.png
#   Missing image: Arabidopsis\2\12d\R3\66.png
#   Missing image: Arabidopsis\2\12d\R3\67.png
#   Missing image: Arabidopsis\2\12d\R3\68.png
#   Missing image: Arabidopsis\2\12d\R3\69.png
#   Missing image: Arabidopsis\2\12d\R3\70.png
#   Missing image: Arabidopsis\2\12d\R3\71.png
#   Missing image: Arabidopsis\2\12d\R3\72.png
# Skipping day 12 for genotype 2, replicate R3 due to missing images.
# day: 13
# day: 14
# day: 15
# day: 16
# day: 17
# day: 18
# Time-lapse video for genotype 2, replicate R3 saved successfully as Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g2_rR3.h5.
#
# Processing genotype 2, replicate R4
# day: 1
# day: 2
# day: 3
# day: 4
# day: 5
# day: 6
# day: 7
# day: 8
# day: 9
# day: 10
# day: 11
# day: 12
#   Missing image: Arabidopsis\2\12d\R4\2.png
#   Missing image: Arabidopsis\2\12d\R4\3.png
#   Missing image: Arabidopsis\2\12d\R4\4.png
#   Missing image: Arabidopsis\2\12d\R4\5.png
#   Missing image: Arabidopsis\2\12d\R4\6.png
#   Missing image: Arabidopsis\2\12d\R4\7.png
#   Missing image: Arabidopsis\2\12d\R4\8.png
#   Missing image: Arabidopsis\2\12d\R4\9.png
#   Missing image: Arabidopsis\2\12d\R4\10.png
#   Missing image: Arabidopsis\2\12d\R4\11.png
#   Missing image: Arabidopsis\2\12d\R4\12.png
#   Missing image: Arabidopsis\2\12d\R4\13.png
#   Missing image: Arabidopsis\2\12d\R4\14.png
#   Missing image: Arabidopsis\2\12d\R4\15.png
#   Missing image: Arabidopsis\2\12d\R4\16.png
#   Missing image: Arabidopsis\2\12d\R4\17.png
#   Missing image: Arabidopsis\2\12d\R4\18.png
#   Missing image: Arabidopsis\2\12d\R4\19.png
#   Missing image: Arabidopsis\2\12d\R4\20.png
#   Missing image: Arabidopsis\2\12d\R4\21.png
#   Missing image: Arabidopsis\2\12d\R4\22.png
#   Missing image: Arabidopsis\2\12d\R4\23.png
#   Missing image: Arabidopsis\2\12d\R4\24.png
#   Missing image: Arabidopsis\2\12d\R4\25.png
#   Missing image: Arabidopsis\2\12d\R4\26.png
#   Missing image: Arabidopsis\2\12d\R4\27.png
#   Missing image: Arabidopsis\2\12d\R4\28.png
#   Missing image: Arabidopsis\2\12d\R4\29.png
#   Missing image: Arabidopsis\2\12d\R4\30.png
#   Missing image: Arabidopsis\2\12d\R4\31.png
#   Missing image: Arabidopsis\2\12d\R4\32.png
#   Missing image: Arabidopsis\2\12d\R4\33.png
#   Missing image: Arabidopsis\2\12d\R4\34.png
#   Missing image: Arabidopsis\2\12d\R4\35.png
#   Missing image: Arabidopsis\2\12d\R4\36.png
#   Missing image: Arabidopsis\2\12d\R4\37.png
#   Missing image: Arabidopsis\2\12d\R4\38.png
#   Missing image: Arabidopsis\2\12d\R4\39.png
#   Missing image: Arabidopsis\2\12d\R4\40.png
#   Missing image: Arabidopsis\2\12d\R4\41.png
#   Missing image: Arabidopsis\2\12d\R4\42.png
#   Missing image: Arabidopsis\2\12d\R4\43.png
#   Missing image: Arabidopsis\2\12d\R4\44.png
#   Missing image: Arabidopsis\2\12d\R4\45.png
#   Missing image: Arabidopsis\2\12d\R4\46.png
#   Missing image: Arabidopsis\2\12d\R4\47.png
#   Missing image: Arabidopsis\2\12d\R4\48.png
#   Missing image: Arabidopsis\2\12d\R4\49.png
#   Missing image: Arabidopsis\2\12d\R4\50.png
#   Missing image: Arabidopsis\2\12d\R4\51.png
#   Missing image: Arabidopsis\2\12d\R4\52.png
#   Missing image: Arabidopsis\2\12d\R4\53.png
#   Missing image: Arabidopsis\2\12d\R4\54.png
#   Missing image: Arabidopsis\2\12d\R4\55.png
#   Missing image: Arabidopsis\2\12d\R4\56.png
#   Missing image: Arabidopsis\2\12d\R4\57.png
#   Missing image: Arabidopsis\2\12d\R4\58.png
#   Missing image: Arabidopsis\2\12d\R4\59.png
#   Missing image: Arabidopsis\2\12d\R4\60.png
#   Missing image: Arabidopsis\2\12d\R4\61.png
#   Missing image: Arabidopsis\2\12d\R4\62.png
#   Missing image: Arabidopsis\2\12d\R4\63.png
#   Missing image: Arabidopsis\2\12d\R4\64.png
#   Missing image: Arabidopsis\2\12d\R4\65.png
#   Missing image: Arabidopsis\2\12d\R4\66.png
#   Missing image: Arabidopsis\2\12d\R4\67.png
#   Missing image: Arabidopsis\2\12d\R4\68.png
#   Missing image: Arabidopsis\2\12d\R4\69.png
#   Missing image: Arabidopsis\2\12d\R4\70.png
#   Missing image: Arabidopsis\2\12d\R4\71.png
#   Missing image: Arabidopsis\2\12d\R4\72.png
# Skipping day 12 for genotype 2, replicate R4 due to missing images.
# day: 13
# day: 14
# day: 15
# day: 16
# day: 17
# day: 18
# Time-lapse video for genotype 2, replicate R4 saved successfully as Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g2_rR4.h5.
#
# Processing genotype 2, replicate R5
# day: 1
# day: 2
# day: 3
# day: 4
# day: 5
# day: 6
# day: 7
# day: 8
# day: 9
# day: 10
# day: 11
# day: 12
#   Missing image: Arabidopsis\2\12d\R5\2.png
#   Missing image: Arabidopsis\2\12d\R5\3.png
#   Missing image: Arabidopsis\2\12d\R5\4.png
#   Missing image: Arabidopsis\2\12d\R5\5.png
#   Missing image: Arabidopsis\2\12d\R5\6.png
#   Missing image: Arabidopsis\2\12d\R5\7.png
#   Missing image: Arabidopsis\2\12d\R5\8.png
#   Missing image: Arabidopsis\2\12d\R5\9.png
#   Missing image: Arabidopsis\2\12d\R5\10.png
#   Missing image: Arabidopsis\2\12d\R5\11.png
#   Missing image: Arabidopsis\2\12d\R5\12.png
#   Missing image: Arabidopsis\2\12d\R5\13.png
#   Missing image: Arabidopsis\2\12d\R5\14.png
#   Missing image: Arabidopsis\2\12d\R5\15.png
#   Missing image: Arabidopsis\2\12d\R5\16.png
#   Missing image: Arabidopsis\2\12d\R5\17.png
#   Missing image: Arabidopsis\2\12d\R5\18.png
#   Missing image: Arabidopsis\2\12d\R5\19.png
#   Missing image: Arabidopsis\2\12d\R5\20.png
#   Missing image: Arabidopsis\2\12d\R5\21.png
#   Missing image: Arabidopsis\2\12d\R5\22.png
#   Missing image: Arabidopsis\2\12d\R5\23.png
#   Missing image: Arabidopsis\2\12d\R5\24.png
#   Missing image: Arabidopsis\2\12d\R5\25.png
#   Missing image: Arabidopsis\2\12d\R5\26.png
#   Missing image: Arabidopsis\2\12d\R5\27.png
#   Missing image: Arabidopsis\2\12d\R5\28.png
#   Missing image: Arabidopsis\2\12d\R5\29.png
#   Missing image: Arabidopsis\2\12d\R5\30.png
#   Missing image: Arabidopsis\2\12d\R5\31.png
#   Missing image: Arabidopsis\2\12d\R5\32.png
#   Missing image: Arabidopsis\2\12d\R5\33.png
#   Missing image: Arabidopsis\2\12d\R5\34.png
#   Missing image: Arabidopsis\2\12d\R5\35.png
#   Missing image: Arabidopsis\2\12d\R5\36.png
#   Missing image: Arabidopsis\2\12d\R5\37.png
#   Missing image: Arabidopsis\2\12d\R5\38.png
#   Missing image: Arabidopsis\2\12d\R5\39.png
#   Missing image: Arabidopsis\2\12d\R5\40.png
#   Missing image: Arabidopsis\2\12d\R5\41.png
#   Missing image: Arabidopsis\2\12d\R5\42.png
# ...
#   Missing image: Arabidopsis\6\12d\R5\24.png
#   Missing image: Arabidopsis\6\12d\R5\25.png
#   Missing image: Arabidopsis\6\12d\R5\26.png
#   Missing image: Arabidopsis\6\12d\R5\27.png
#   Missing image: Arabidopsis\6\12d\R5\28.png
#   Missing image: Arabidopsis\6\12d\R5\29.png
#   Missing image: Arabidopsis\6\12d\R5\30.png
#   Missing image: Arabidopsis\6\12d\R5\31.png
#   Missing image: Arabidopsis\6\12d\R5\32.png
#   Missing image: Arabidopsis\6\12d\R5\33.png
#   Missing image: Arabidopsis\6\12d\R5\34.png
#   Missing image: Arabidopsis\6\12d\R5\35.png
#   Missing image: Arabidopsis\6\12d\R5\36.png
#   Missing image: Arabidopsis\6\12d\R5\37.png
#   Missing image: Arabidopsis\6\12d\R5\38.png
#   Missing image: Arabidopsis\6\12d\R5\39.png
#   Missing image: Arabidopsis\6\12d\R5\40.png
#   Missing image: Arabidopsis\6\12d\R5\41.png
#   Missing image: Arabidopsis\6\12d\R5\42.png
#   Missing image: Arabidopsis\6\12d\R5\43.png
#   Missing image: Arabidopsis\6\12d\R5\44.png
#   Missing image: Arabidopsis\6\12d\R5\45.png
#   Missing image: Arabidopsis\6\12d\R5\46.png
#   Missing image: Arabidopsis\6\12d\R5\47.png
#   Missing image: Arabidopsis\6\12d\R5\48.png
#   Missing image: Arabidopsis\6\12d\R5\49.png
#   Missing image: Arabidopsis\6\12d\R5\50.png
#   Missing image: Arabidopsis\6\12d\R5\51.png
#   Missing image: Arabidopsis\6\12d\R5\52.png
#   Missing image: Arabidopsis\6\12d\R5\53.png
#   Missing image: Arabidopsis\6\12d\R5\54.png
#   Missing image: Arabidopsis\6\12d\R5\55.png
#   Missing image: Arabidopsis\6\12d\R5\56.png
#   Missing image: Arabidopsis\6\12d\R5\57.png
#   Missing image: Arabidopsis\6\12d\R5\58.png
#   Missing image: Arabidopsis\6\12d\R5\59.png
#   Missing image: Arabidopsis\6\12d\R5\60.png
#   Missing image: Arabidopsis\6\12d\R5\61.png
#   Missing image: Arabidopsis\6\12d\R5\62.png
#   Missing image: Arabidopsis\6\12d\R5\63.png
#   Missing image: Arabidopsis\6\12d\R5\64.png
#   Missing image: Arabidopsis\6\12d\R5\65.png
#   Missing image: Arabidopsis\6\12d\R5\66.png
#   Missing image: Arabidopsis\6\12d\R5\67.png
#   Missing image: Arabidopsis\6\12d\R5\68.png
#   Missing image: Arabidopsis\6\12d\R5\69.png
#   Missing image: Arabidopsis\6\12d\R5\70.png
#   Missing image: Arabidopsis\6\12d\R5\71.png
#   Missing image: Arabidopsis\6\12d\R5\72.png
# Skipping day 12 for genotype 6, replicate R5 due to missing images.
# day: 13
# day: 14
# day: 15
# day: 16
# day: 17
# day: 18
# Time-lapse video for genotype 6, replicate R5 saved successfully as Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR5.h5.
#
# Processing genotype 6, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR5.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R1
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR1.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R2
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR2.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R3
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR3.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R4
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR4.h5 as it already exists and overwrite is False.
#
# Processing genotype 6, replicate R5
# Skipping Arabidopsis_time_lapse_videos_20240807\h5s_preds_by_frame\g6_rR5.h5 as it already exists and overwrite is False.
