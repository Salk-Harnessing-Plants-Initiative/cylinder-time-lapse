# %%
import numpy as np
import os
import h5py
import skvideo.io

from pathlib import Path
from typing import List

# %%
def find_all_series(data_folders: List[str]) -> List[str]:
    """Find all .h5 series from a list of folders.
    
    Args:
        data_folders: List of paths to folders containing .h5 series.
    
    Returns:
        A list of filenames to .h5 series.
    """
    h5_series = []
    for data_folder in data_folders:
        # h5_series.extend([Path(p).as_posix() for p in glob(f"{data_folder}/*.h5")])
        h5_series.extend([p.as_posix() for p in Path(data_folder).rglob("*.h5")])
    return h5_series


def render_plant_from_h5(h5_path, save_path, decimate=4, slowdown_factor=1, x0=512, x1=1536, overwrite=False):
    """Create an MP4 video from a dataset within an H5 file.
    
    Args:
        h5_path: Path to the H5 file containing the 'vol' dataset with images.
        save_path: Path where the output MP4 video will be saved.
        decimate: Factor by which the images will be decimated (reduced in resolution).
        slowdown_factor: Factor by which the video playback will be slowed down.
        x0, x1: Horizontal bounds for cropping the image.
        overwrite: If False, existing videos will not be overwritten.
    
    Returns:
        None. The video is saved to the specified path if it does not exist or overwrite is True.
    """
    save_path = Path(save_path)
    if save_path.exists() and not overwrite:
        print(f"Video {save_path} already exists. Skipping due to overwrite=False.")
        return
    
    print(f"Opening H5 file: {h5_path}")
    with h5py.File(h5_path, 'r') as f:
        print("Reading 'vol' dataset from H5 file...")
        data = f['vol'][:]
        print(f"Dataset shape: {data.shape}")
    
    out_video = []
    print("Processing images...")
    for i, img in enumerate(data):
        # Crop and decimate
        # img = img[:, x0:x1]
        img = img[::decimate, ::decimate]
        if i % 10 == 0:  # Print progress every 10 frames
            print(f"Processed {i+1}/{len(data)} frames...")
        out_video.append(img)
    
    out_video = np.stack(out_video, axis=0)
    print(f"Total frames before slowdown: {len(out_video)}")
    
    if slowdown_factor > 1:
        out_video = np.repeat(out_video, slowdown_factor, axis=0)
        print(f"Applied slowdown factor. Total frames after slowdown: {len(out_video)}")
    
    # Ensure the video is in the correct format for skvideo to write
    out_video = out_video.astype(np.uint8)
    
    print(f"Writing video to {save_path}...")
    skvideo.io.vwrite(str(save_path), out_video)
    print("Video creation completed.")

# %%
# Path to find h5s and save mp4s (1 per h5)
base_dir = Path('Sorghum_time_lapse_videos_one_frame_per_day_20240808') / "h5s_preds_by_frame"

# %%
# If overwrite=True mp4s will be overwritten
overwrite = True
decimation = 2 # Factor used to coarsen the video 
# x0, x1 = (550, 1630) # cropping
# x1 = ((x1 - x0) // (4 * decimation)) * (4 * decimation) + x0 # adjusted cropping
slowdown_factor = 5  # must be integer >= 1

# %%
# Check current working directory
print(f"Current working directory: {os.getcwd()}")
print(f"Looking in: {base_dir.absolute()}")  # Print the absolute path for clarity

# Ensure the directory exists
if not base_dir.exists():
    print(f"The directory {base_dir.absolute()} does not exist.")
else:
    # Attempt to find and process .h5 files
    # Find all .h5 files within the base directory and its subdirectories
    for h5_file in base_dir.glob('**/*.h5'):
        mp4_file = h5_file.with_suffix('.mp4')
        print(f"Processing {h5_file}...")
        render_plant_from_h5(h5_file, mp4_file, decimate=4, slowdown_factor=slowdown_factor, x0=512, x1=1536, overwrite=overwrite)
        print(f"Made {mp4_file}...")
# Out:
# Current working directory: C:\Users\eb\Box\elohim_bello\final_time_lapse_images
# Looking in: C:\Users\eb\Box\elohim_bello\final_time_lapse_images\Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g1_rR1.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g1_rR1.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (14, 1080, 2048, 1)
# Processing images...
# Processed 1/14 frames...
# Processed 11/14 frames...
# Total frames before slowdown: 14
# Applied slowdown factor. Total frames after slowdown: 70
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g1_rR1.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g1_rR1.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g1_rR2.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g1_rR2.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (14, 1080, 2048, 1)
# Processing images...
# Processed 1/14 frames...
# Processed 11/14 frames...
# Total frames before slowdown: 14
# Applied slowdown factor. Total frames after slowdown: 70
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g1_rR2.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g1_rR2.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g1_rR3.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g1_rR3.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (14, 1080, 2048, 1)
# Processing images...
# Processed 1/14 frames...
# Processed 11/14 frames...
# Total frames before slowdown: 14
# Applied slowdown factor. Total frames after slowdown: 70
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g1_rR3.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g1_rR3.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g1_rR4.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g1_rR4.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (14, 1080, 2048, 1)
# Processing images...
# Processed 1/14 frames...
# Processed 11/14 frames...
# Total frames before slowdown: 14
# Applied slowdown factor. Total frames after slowdown: 70
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g1_rR4.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g1_rR4.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g1_rR5.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g1_rR5.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (11, 1080, 2048, 1)
# Processing images...
# Processed 1/11 frames...
# Processed 11/11 frames...
# Total frames before slowdown: 11
# Applied slowdown factor. Total frames after slowdown: 55
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g1_rR5.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g1_rR5.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g2_rR1.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g2_rR1.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (14, 1080, 2048, 1)
# Processing images...
# Processed 1/14 frames...
# Processed 11/14 frames...
# Total frames before slowdown: 14
# Applied slowdown factor. Total frames after slowdown: 70
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g2_rR1.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g2_rR1.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g2_rR2.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g2_rR2.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (14, 1080, 2048, 1)
# Processing images...
# Processed 1/14 frames...
# Processed 11/14 frames...
# Total frames before slowdown: 14
# Applied slowdown factor. Total frames after slowdown: 70
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g2_rR2.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g2_rR2.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g2_rR3.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g2_rR3.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (7, 1080, 2048, 1)
# Processing images...
# Processed 1/7 frames...
# Total frames before slowdown: 7
# Applied slowdown factor. Total frames after slowdown: 35
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g2_rR3.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g2_rR3.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g2_rR4.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g2_rR4.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (14, 1080, 2048, 1)
# Processing images...
# Processed 1/14 frames...
# Processed 11/14 frames...
# Total frames before slowdown: 14
# Applied slowdown factor. Total frames after slowdown: 70
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g2_rR4.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g2_rR4.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g2_rR5.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g2_rR5.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (14, 1080, 2048, 1)
# Processing images...
# Processed 1/14 frames...
# Processed 11/14 frames...
# Total frames before slowdown: 14
# Applied slowdown factor. Total frames after slowdown: 70
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g2_rR5.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g2_rR5.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g3_rR1.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g3_rR1.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (14, 1080, 2048, 1)
# Processing images...
# Processed 1/14 frames...
# Processed 11/14 frames...
# Total frames before slowdown: 14
# Applied slowdown factor. Total frames after slowdown: 70
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g3_rR1.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g3_rR1.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g3_rR2.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g3_rR2.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (14, 1080, 2048, 1)
# Processing images...
# Processed 1/14 frames...
# Processed 11/14 frames...
# Total frames before slowdown: 14
# Applied slowdown factor. Total frames after slowdown: 70
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g3_rR2.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g3_rR2.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g3_rR3.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g3_rR3.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (7, 1080, 2048, 1)
# Processing images...
# Processed 1/7 frames...
# Total frames before slowdown: 7
# Applied slowdown factor. Total frames after slowdown: 35
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g3_rR3.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g3_rR3.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g3_rR4.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g3_rR4.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (6, 1080, 2048, 1)
# Processing images...
# Processed 1/6 frames...
# Total frames before slowdown: 6
# Applied slowdown factor. Total frames after slowdown: 30
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g3_rR4.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g3_rR4.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g3_rR5.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g3_rR5.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (10, 1080, 2048, 1)
# Processing images...
# Processed 1/10 frames...
# Total frames before slowdown: 10
# Applied slowdown factor. Total frames after slowdown: 50
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g3_rR5.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g3_rR5.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g4_rR1.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g4_rR1.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (8, 1080, 2048, 1)
# Processing images...
# Processed 1/8 frames...
# Total frames before slowdown: 8
# Applied slowdown factor. Total frames after slowdown: 40
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g4_rR1.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g4_rR1.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g4_rR2.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g4_rR2.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (14, 1080, 2048, 1)
# Processing images...
# Processed 1/14 frames...
# Processed 11/14 frames...
# Total frames before slowdown: 14
# Applied slowdown factor. Total frames after slowdown: 70
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g4_rR2.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g4_rR2.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g4_rR3.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g4_rR3.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (14, 1080, 2048, 1)
# Processing images...
# Processed 1/14 frames...
# Processed 11/14 frames...
# Total frames before slowdown: 14
# Applied slowdown factor. Total frames after slowdown: 70
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g4_rR3.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g4_rR3.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g4_rR4.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g4_rR4.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (10, 1080, 2048, 1)
# Processing images...
# Processed 1/10 frames...
# Total frames before slowdown: 10
# Applied slowdown factor. Total frames after slowdown: 50
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g4_rR4.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g4_rR4.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g4_rR5.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g4_rR5.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (14, 1080, 2048, 1)
# Processing images...
# Processed 1/14 frames...
# Processed 11/14 frames...
# Total frames before slowdown: 14
# Applied slowdown factor. Total frames after slowdown: 70
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g4_rR5.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g4_rR5.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g5_rR1.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g5_rR1.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (14, 1080, 2048, 1)
# Processing images...
# Processed 1/14 frames...
# Processed 11/14 frames...
# Total frames before slowdown: 14
# Applied slowdown factor. Total frames after slowdown: 70
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g5_rR1.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g5_rR1.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g5_rR2.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g5_rR2.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (14, 1080, 2048, 1)
# Processing images...
# Processed 1/14 frames...
# Processed 11/14 frames...
# Total frames before slowdown: 14
# Applied slowdown factor. Total frames after slowdown: 70
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g5_rR2.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g5_rR2.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g5_rR3.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g5_rR3.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (14, 1080, 2048, 1)
# Processing images...
# Processed 1/14 frames...
# Processed 11/14 frames...
# Total frames before slowdown: 14
# Applied slowdown factor. Total frames after slowdown: 70
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g5_rR3.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g5_rR3.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g5_rR4.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g5_rR4.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (9, 1080, 2048, 1)
# Processing images...
# Processed 1/9 frames...
# Total frames before slowdown: 9
# Applied slowdown factor. Total frames after slowdown: 45
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g5_rR4.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g5_rR4.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g5_rR5.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g5_rR5.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (13, 1080, 2048, 1)
# Processing images...
# Processed 1/13 frames...
# Processed 11/13 frames...
# Total frames before slowdown: 13
# Applied slowdown factor. Total frames after slowdown: 65
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g5_rR5.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g5_rR5.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g6_rR1.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g6_rR1.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (14, 1080, 2048, 1)
# Processing images...
# Processed 1/14 frames...
# Processed 11/14 frames...
# Total frames before slowdown: 14
# Applied slowdown factor. Total frames after slowdown: 70
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g6_rR1.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g6_rR1.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g6_rR2.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g6_rR2.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (14, 1080, 2048, 1)
# Processing images...
# Processed 1/14 frames...
# Processed 11/14 frames...
# Total frames before slowdown: 14
# Applied slowdown factor. Total frames after slowdown: 70
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g6_rR2.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g6_rR2.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g6_rR3.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g6_rR3.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (9, 1080, 2048, 1)
# Processing images...
# Processed 1/9 frames...
# Total frames before slowdown: 9
# Applied slowdown factor. Total frames after slowdown: 45
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g6_rR3.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g6_rR3.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g6_rR4.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g6_rR4.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (14, 1080, 2048, 1)
# Processing images...
# Processed 1/14 frames...
# Processed 11/14 frames...
# Total frames before slowdown: 14
# Applied slowdown factor. Total frames after slowdown: 70
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g6_rR4.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g6_rR4.mp4...
# Processing Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g6_rR5.h5...
# Opening H5 file: Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g6_rR5.h5
# Reading 'vol' dataset from H5 file...
# Dataset shape: (14, 1080, 2048, 1)
# Processing images...
# Processed 1/14 frames...
# Processed 11/14 frames...
# Total frames before slowdown: 14
# Applied slowdown factor. Total frames after slowdown: 70
# Writing video to Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g6_rR5.mp4...
# Video creation completed.
# Made Sorghum_time_lapse_videos_one_frame_per_day_20240808\h5s_preds_by_frame\g6_rR5.mp4...
